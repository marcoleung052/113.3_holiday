# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# 載入預訓練模型和 tokenizer
model = GPT2LMHeadModel.from_pretrained("gpt2")
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
input_text = "他們"
input_ids = tokenizer.encode(input_text, return_tensors="pt")

output = model.generate(
    input_ids,
    max_length=20,
    num_return_sequences=3,
    do_sample=True,
    top_k=50,
    temperature=0.9,
    pad_token_id=tokenizer.pad_token_id
)

print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# 他們囼増的认为中國

# %%
import gradio as gr

def autocomplete(text):
    input_ids = tokenizer.encode(text, return_tensors="pt")
    output = model.generate(
        input_ids,
        max_length=20,
        num_return_sequences=1,
        no_repeat_ngram_size=2,
        top_k=50,
        temperature=1.0,
        do_sample=True,
        pad_token_id=tokenizer.eos_token_id
    )
    return [tokenizer.decode(o, skip_special_tokens=True) for o in output]

gr.Interface(fn=autocomplete, inputs="text", outputs=gr.Textbox(type="text", label="Completions", lines=3), live=True).launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://eeae5d6baa46caebb2.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://eeae5d6baa46caebb2.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
from transformers import BertTokenizerFast
from transformers.models.gpt2.modeling_gpt2 import GPT2LMHeadModel

# 載入繁體中文 tokenizer 和模型
tokenizer = BertTokenizerFast.from_pretrained("ckiplab/gpt2-base-chinese")
model = GPT2LMHeadModel.from_pretrained("ckiplab/gpt2-base-chinese")
# Out:
# tokenizer_config.json:   0%|          | 0.00/174 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/758 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/421M [00:00<?, ?B/s]

# %%
input_text = "他們"
input_ids = tokenizer.encode(input_text, return_tensors="pt")

output = model.generate(
    input_ids,
    max_length=20,
    num_return_sequences=3,
    do_sample=True,
    top_k=50,
    temperature=0.9,
    pad_token_id=tokenizer.pad_token_id
)

print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# 他 們 來 到 美 國 。 他 們 在 紐 約 與 紐 約 之 間 的

# %%
input_text = "他們"
input_ids = tokenizer.encode(input_text, return_tensors="pt")

output = model.generate(
    input_ids,
    max_length=50,
    num_return_sequences=3,
    do_sample=True,
    top_k=50,
    temperature=0.9,
    pad_token_id=tokenizer.pad_token_id
)

print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# 他 們, 從 一 九 八 七 年 開 始, 北 京 市 的 人 民 政 府 和 商 務 部 長 也 都 進 行 了 對 話, 並 與 其 他 地 區 政 府 就 地 方 交 流 問 題

# %%
import gradio as gr

def autocomplete(text):
    input_ids = tokenizer.encode(text, return_tensors="pt")
    output = model.generate(
        input_ids,
        max_length=20,
        num_return_sequences=1,
        no_repeat_ngram_size=2,
        top_k=50,
        temperature=1.0,
        do_sample=True,
        pad_token_id=tokenizer.eos_token_id
    )
    return [tokenizer.decode(o, skip_special_tokens=True) for o in output]

gr.Interface(fn=autocomplete, inputs="text", outputs=gr.Textbox(type="text", label="Completions", lines=3), live=True).launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://bcc4ff26808e4e3c2c.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://bcc4ff26808e4e3c2c.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel

model_name = 'IDEA-CCNL/Wenzhong-GPT2-110M'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/236 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/783 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/274M [00:00<?, ?B/s]

# %%
input_text = "他們"
input_ids = tokenizer.encode(input_text, return_tensors="pt")

output = model.generate(
    input_ids,
    max_length=50,
    num_return_sequences=3,
    do_sample=True,
    top_k=50,
    temperature=0.9,
    pad_token_id=tokenizer.pad_token_id
)
print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 他們肩摔倒，霎时刹车可见车后有跟着的感�

# %%
import gradio as gr

def autocomplete(text):
    input_ids = tokenizer.encode(text, return_tensors="pt")
    output = model.generate(
        input_ids,
        max_length=20,
        num_return_sequences=1,
        no_repeat_ngram_size=2,
        top_k=50,
        temperature=1.0,
        do_sample=True,
        pad_token_id=tokenizer.eos_token_id
    )
    return [tokenizer.decode(o, skip_special_tokens=True) for o in output]

gr.Interface(fn=autocomplete, inputs="text", outputs=gr.Textbox(type="text", label="Completions", lines=3), live=True).launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://8faffdbc719c051e0f.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://8faffdbc719c051e0f.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
from flask import Flask, request, jsonify
from transformers import GPT2LMHeadModel, BertTokenizerFast

model = GPT2LMHeadModel.from_pretrained("uer/gpt2-chinese-cluecorpussmall")
tokenizer = BertTokenizerFast.from_pretrained("uer/gpt2-chinese-cluecorpussmall")
# Out:
# config.json:   0%|          | 0.00/577 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/421M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/217 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/421M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
input_text = "他們"
input_ids = tokenizer.encode(input_text, return_tensors="pt")

output = model.generate(
    input_ids,
    max_length=50,
    num_return_sequences=3,
    do_sample=True,
    top_k=50,
    temperature=0.9,
    pad_token_id=tokenizer.pad_token_id
)

print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# 他 們 的 菜 味 道 和 數 據 都 很 好 ， 服 務 態 度 也 都 挺 好 ， 菜 價 也 合 理 ， 所 以 生 意 很 好 ， 適 合 公 司 集 體 活 動 ， 公 司 請 客

# %%
app = Flask(__name__)

@app.route("/generate", methods=["POST"])
def generate():
    data = request.json
    input_text = data.get("text", "")
    input_ids = tokenizer.encode(input_text, return_tensors="pt")
    output = model.generate(
        input_ids,
        max_length=len(input_ids[0]) + 50,
        do_sample=True,
        top_k=50,
        temperature=0.9,
        pad_token_id=tokenizer.pad_token_id
    )
    result = tokenizer.decode(output[0], skip_special_tokens=True)
    return jsonify({"result": result})

# %%
def generate_options_with_scores(prompt, num_options=5):
    input_ids = tokenizer.encode(prompt, return_tensors="pt")
    outputs = model.generate(
        input_ids,
        max_length=len(input_ids[0]) + 50,
        num_return_sequences=num_options,
        do_sample=True,
        top_k=50,
        temperature=0.9,
        pad_token_id=tokenizer.pad_token_id,
        output_scores=True,
        return_dict_in_generate=True
    )

    results = []
    for sequence, score_set in zip(outputs.sequences, outputs.scores):
        # 計算整體 log-probability，越大代表越高機率
        logprobs = [score.max().item() for score in score_set]
        total_score = sum(logprobs)

        # 解碼文字
        text = tokenizer.decode(sequence, skip_special_tokens=True)
        results.append((text, total_score))

    return results

# %%
# 主程式迴圈
def generate_options(prompt, num_options=5):
    input_ids = tokenizer.encode(prompt, return_tensors="pt")
    outputs = model.generate(
        input_ids,
        max_length=len(input_ids[0]) + 50,
        num_return_sequences=num_options,
        do_sample=True,
        top_k=50,
        temperature=0.9,
        pad_token_id=tokenizer.pad_token_id
    )
    results = [tokenizer.decode(output, skip_special_tokens=True) for output in outputs]
    return results

# %%
while True:
  text = input("請輸入文字（按 Enter 結束）：")
  if not text.strip():
    break
  completions = generate_options_with_scores(text)
  print("GPT-2 補全建議：")
  for i, c in enumerate(completions):
    print(f"{i+1}. {c}")
  print("-" * 40)
# Out:
# 請輸入文字（按 Enter 結束）：人
# GPT-2 補全建議：
# 1. ('人 （ ， ） ， 出 身 于 台 湾 桃 园 市 ， 曾 任 桃 园 市 政 府 委 员 。 她 是 台 湾 历 史 最 悠 久 的 女 性 政 府 首 脑 之 一 ， 现 任 内 政 部 经 济 司', 31.319023609161377)
# 2. ('人 的 一 生 中 有 多 少 次 被 自 己 的 父 母 欺 骗 了 ？ 人 如 果 被 父 母 的 欺 骗 而 被 这 个 社 会 欺 骗 了 ， 而 且 是 自 己 的 父 母 欺 骗 了 自 己', 49.23657846450806)
# 3. ('人 的 生 命 因 为 有 了 这 个 故 事 让 我 感 动 了 好 多 还 买 了 别 的 几 本 书 但 是 都 很 有 趣 这 个 故 事 真 的 很 有 爱 。 值 得', 60.50465774536133)
# 4. ('人 不 多 ， 但 是 服 务 员 的 态 度 很 一 般 ， 叫 点 蜡 烛 的 时 候 ， 还 会 来 催 促 ， 而 且 也 觉 得 那 个 灯 太 暗 了 ， 如 果 不 是 因 为 很 饿 ，', 46.49310874938965)
# 5. ('人 先 生 是 怎 么 被 一 套 书 封 面 给 吸 引 住 的 呢 书 的 内 容 对 于 那 些 对 《 一 些 知 识 点 概 括 概 念 》 很 感 兴 趣 一 位 有 着 丰 富 经 验 的', 57.091185569763184)
# ----------------------------------------
# 請輸入文字（按 Enter 結束）：醫生
# GPT-2 補全建議：
# 1. ('醫 生 （ 英 文 ： medical staff ） 是 一 位 醫 治 疾 病 的 專 家 ， 於 1973 年 出 版 的 「 医 生 」 ( the company ) 杂 志 以 及 香 港 、 上 海 的 「 美 術 師 」', 44.81134033203125)
# 2. ('醫 生 切 口 會 有 點 疼 是 什 麼 情 況 ？ 就 是 說 大 多 數 人 沒 有 經 過 拔 智 齒 去 醫 院 拔 智 齒 的 經 驗 。 因 為 智 齒 沒 那 麼 疼 了 ， 所 以 想 問', 37.221495628356934)

    input_ids = tokenizer.encode(prompt, return_tensors="pt")
    outputs = model.generate(
        input_ids,
        max_length=len(input_ids[0]) + 10,
        num_return_sequences=num_options,
        do_sample=True,
        top_k=50,
        temperature=0.9,
        pad_token_id=tokenizer.pad_token_id,
        output_scores=True,
        return_dict_in_generate=True
    )

    results = []
    for sequence, score_set in zip(outputs.sequences, outputs.scores):
        # 解碼並移除原始 prompt 部分
        prompt_len = len(input_ids[0])
        full_text = tokenizer.decode(sequence, skip_special_tokens=True)
        continuation = tokenizer.decode(sequence[prompt_len:], skip_special_tokens=True).strip()

        # 簡單 log-prob 統計（可自定）
        logprobs = [score.max().item() for score in score_set]
        total_score = sum(logprobs)

        results.append((continuation.replace(" ", ""), total_score))

    return results

# %%
current_text = ""

while True:
    if not current_text:
        user_input = input("請輸入開頭句子（或 Enter 離開）：").strip()
        if not user_input:
            break
        current_text = user_input

    completions = generate_options_with_scores(current_text)
    print("\n補全建議:")
    for i, (cont, score) in enumerate(completions):
        print(f"{i + 1}. {cont}  ({score:.2f})")

    action = input("\n輸入編號選擇句子，或輸入 next / again： ").strip().lower()

    if action == "next":
        current_text = ""
        continue
    elif action == "again":
        continue
    elif action.isdigit():
        idx = int(action) - 1
        if 0 <= idx < len(completions):
            selected = completions[idx][0]
            current_text += selected
            print(f"\n已接續句子：{current_text}\n")
        else:
            print("選項超出範圍")
    else:
        print("請輸入合法的選項")

    print("-" * 50)
# Out:
# 請輸入開頭句子（或 Enter 離開）：他們
#
# 補全建議:
# 1. 態度還不錯沒有像其他  (38.17)
# 2. 的服务很差.點個菜等  (55.00)
# 3. 料的很足，不過有些有  (64.44)
# 4. 面做的很好，有些菜  (62.22)
# 5. 的自助餐不錯的選擇.  (62.72)
#
# 輸入編號選擇句子，或輸入 next / again： 3
#
# 已接續句子：他們料的很足，不過有些有
#
# --------------------------------------------------
#
# 補全建議:
# 1. ，也不敢太多，總之每  (53.45)
# 2. 的沒有給你，有的等你  (43.66)
# 3. 的味道就不怎麼樣了。  (64.53)
# 4. 的就不是很有鮮味了。  (55.77)
# 5. ，但是在中區來說，他  (54.71)
#
# 輸入編號選擇句子，或輸入 next / again： 3
#
# 已接續句子：他們料的很足，不過有些有的味道就不怎麼樣了。
#
# --------------------------------------------------
#
# 補全建議:
# 1. 塊大的小丸子真的是價  (44.86)
# 2. 燒餅、羊肉串、肉夾馍  (49.14)
# 3. 樂扣的杯子挺好，杯子  (51.84)
# 4. 塊錢5塊錢的牛肉米粉  (51.60)
# 5. 甸街的味道還不錯，雖  (69.58)
#
# 輸入編號選擇句子，或輸入 next / again： 5
#
# 已接續句子：他們料的很足，不過有些有的味道就不怎麼樣了。甸街的味道還不錯，雖
#
# --------------------------------------------------
#
# 補全建議:
# 1. 也不算好吃。沒有嘗到  (47.47)
# 2. 但是也沒有那麼好吃。  (49.52)
# 3. ，味道也不錯。不過價  (56.21)
# 4. ，有空去嘗嘗。，，  (58.69)
# 5. 能夠吃過癮，但是總是  (59.04)
#
# 輸入編號選擇句子，或輸入 next / again： 5
#
# 已接續句子：他們料的很足，不過有些有的味道就不怎麼樣了。甸街的味道還不錯，雖能夠吃過癮，但是總是
#
# --------------------------------------------------
#
# 補全建議:
# 1. 外觀上看就不怎麼樣的  (46.72)
# 2. 想吃回去，但是還是不  (55.84)
# 3. 料不足。一樓的麻辣燙  (63.05)
# 4. 得留下一些印象。邊  (55.28)
# 5. 留不住人心。我就是喜  (56.71)
#
# 輸入編號選擇句子，或輸入 next / again： again
#
# 補全建議:
# 1. 久久不能散去，所以我  (46.72)
# 2. 味道超重。沒有其他的  (59.62)
# 3. 想想太膩了所以沒有太  (59.53)
# 4. 過不了那個瘾人還是會  (62.40)
# 5. 得吃一次啊的感覺。  (63.55)
#
# 輸入編號選擇句子，或輸入 next / again： 2
#
# 已接續句子：他們料的很足，不過有些有的味道就不怎麼樣了。甸街的味道還不錯，雖能夠吃過癮，但是總是味道超重。沒有其他的
#
# --------------------------------------------------
#
# 補全建議:
# 1. 。價格也很便宜，還  (50.40)
# 2. 。條也行。條蠻好  (52.14)
# 3. ，不過也許是他們的生  (62.26)
# 4. 食小店好吃，但是也很  (49.14)
# 5. 吃。飯也是不錯的  (61.49)
#
# 輸入編號選擇句子，或輸入 next / again： next
# 請輸入開頭句子（或 Enter 離開）：我們今天要去
#
# 補全建議:
# 1. 的就是這家！環境挺好  (34.97)
# 2. 個好吃的.環境很不錯  (37.43)
# 3. 在北京的一家很多很棒  (58.55)
# 4. 看一場紀錄片，但是那  (46.76)
# 5. 買書了，還沒有到的書  (52.59)
#
# 輸入編號選擇句子，或輸入 next / again： again
#
# 補全建議:
# 1. 排隊了，幸好我們早早  (34.97)
# 2. 跟一個很好的朋友吃飯  (50.92)
# 3. 是因為去年有一個很大  (67.11)
# 4. 提升中国的文化品位！  (49.16)
# 5. 家附近吃這個店很好可  (44.71)
#
# 輸入編號選擇句子，或輸入 next / again： 2
#
# 已接續句子：我們今天要去跟一個很好的朋友吃飯
#
# --------------------------------------------------
#
# 補全建議:
# 1. 先问了一下店家一般都  (49.44)
# 2. 到了那里真是感觉比較  (52.12)
# 3. 想去看看他家餐厅怎么  (50.99)
# 4. 由于是商場下面的緣故  (56.79)
# 5. 地很早就訂好了我就在  (61.75)
#
# 輸入編號選擇句子，或輸入 next / again： 5
#
# 已接續句子：我們今天要去跟一個很好的朋友吃飯地很早就訂好了我就在
#
# --------------------------------------------------
#
# 補全建議:
# 1. 在上課的時候去那裡的  (40.32)
# 2. 村我們選擇了這家店環  (57.91)
# 3. 公公房訂了一間包房去  (53.01)
# 4. 立方附近兜兜轉轉順着  (60.37)
# 5. 附近找餐廳不過剛好看  (64.69)
#
# 輸入編號選擇句子，或輸入 next / again：
# 請輸入合法的選項
# --------------------------------------------------
#
# 補全建議:
# 1. 地吃飯他在這裡吃午飯  (40.32)
# 2. 間酒店住但是我們去之  (46.53)
# 3. 住所附近所以一直沒去  (60.73)
# 4. 早上去的那個地方人很  (69.67)
# 5. 早的時候去的人不是很  (48.98)
#
# 輸入編號選擇句子，或輸入 next / again：
# 請輸入合法的選項
# --------------------------------------------------
#
# 補全建議:
# 1. 旁邊坐下了點了一個焗  (40.32)
# 2. 村吃的晚饭和朋友去的  (58.01)
# 3. 根酒家旁邊有一個很大  (54.19)
# 4. 一旁發呆了她們下次還  (54.60)
# 5. 旁邊就來到了這家菜館  (63.57)
#
# 輸入編號選擇句子，或輸入 next / again： next
# 請輸入開頭句子（或 Enter 離開）：
